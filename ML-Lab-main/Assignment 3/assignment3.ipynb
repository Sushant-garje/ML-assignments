# %%
'''# Visualize the data using R/Python by plotting the graphs for assignment no. 1 and 2. Consider 
# suitable data set. Use Scatter plot, Bar plot, Box plot, Pie chart, Line Chart.'''

# %%
#importing necessary libtaries
# %pip install seaborn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = pd.read_csv(r'C:\Users\jnira\Downloads\ML_Lab-main\ML_Lab-main\Assignment 3\admission - admission.csv')

# %%
dataset.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
#bar chart
plt.bar(dataset["University Rating"], dataset["Chance of Admit"])
plt.xlabel("Chance of Admit")
plt.ylabel("University Rating")
plt.title("University Rating VS Chance of Admit")
plt.show()

# %%
#scatterplot
plt.scatter(dataset["GRE Score"], dataset["TOEFL Score"], color = 'blue')
plt.xlabel("TOEFL Score")
plt.ylabel("GRE Score")
plt.title("GRE Score VS TOEFL Score")
plt.show()

# %%
#boxplot
sns.boxplot(x = "CGPA", data = dataset, showmeans="True", color = "blue")
plt.title('Box Plot of CGPA')
# Out:
# Text(0.5, 1.0, 'Box Plot of CGPA')

# %%
#boxplot
plt.figure(figsize=(6,4))
sns.boxplot(x=dataset['University Rating'], y=dataset['TOEFL Score'], color = 'blue')
plt.title('University Rating vs TOEFL Score')
plt.show()

# %%
#pie chart
plt.figure(figsize=(6,6))
research = dataset['Research'].value_counts()
plt.pie(research, labels=['Research (1)', 'No Research (0)'], autopct='%1.1f%%', colors=['red', 'orange',])
plt.title('Proportions of Research')
plt.show()

# %%
#line chart
plt.plot(dataset["Serial No."], dataset["CGPA"], color = 'orange')
plt.xlabel('Serial No.')
plt.ylabel('CGPA')
plt.title('')
plt.show()
